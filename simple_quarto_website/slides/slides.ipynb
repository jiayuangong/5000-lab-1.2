# %% [markdown]
# ---
# title: "DSAN-5000 Lab 3 — Mini Presentation"
# author: "Jiayuan (Jay) Gong"
# format:
#   revealjs:
#     slide-number: true
#     code-fold: true
#     toc: false
# bibliography: ../reference.bib
# execute:
#   echo: true
# ---

# %% [markdown]
# # Introduction
#
# Welcome to this mini slide deck for **DSAN-5000 Lab 3**.
# This deck demonstrates Reveal.js integration in Quarto.
#
# Citation example: Transformers revolutionized NLP [@NIPS2017_3f5ee243].

# %% [markdown]
# ## Visualization Examples
#
# ![](images/figure-01.jpg){width=48%} \
# ![](images/figure-02.jpg){width=48%}

# %% [markdown]
# ## Python Demo
#
# The following Python code cell is folded by default, but the output plot is shown.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2*np.pi, 200)
y = np.cos(x)

plt.figure(figsize=(6,4))
plt.plot(x, y, color="darkorange", label="cos(x)")
plt.title("Cosine Function Example")
plt.xlabel("x")
plt.ylabel("cos(x)")
plt.legend()
plt.grid(True)
plt.show()
